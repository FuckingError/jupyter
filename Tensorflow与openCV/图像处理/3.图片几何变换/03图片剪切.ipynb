# %%
#剪切x 100 到 200  y 100 到 300

# %%
import cv2
for i in range(1,208):
    img = cv2.imread('ne/'+str(i)+'.jpg',1) #../上层目录  ./当前目录
    imgInfo = img.shape
    print(imgInfo)
    if i==0:
        break
    dst = img[26:90,0:128]
    cv2.imwrite('neg/'+str(i+230)+'.jpg',dst)
print('end')
# Out:
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# (96, 128, 3)
# ...

# %%
# Out:
# (96, 118, 3)

# %%
cv2.imshow('image',dst)
cv2.imshow('xyt',img)
cv2.waitKey()
