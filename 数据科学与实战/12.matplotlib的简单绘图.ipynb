# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [1,2,3]
b = [4,5,6]
plt.plot(a,b)

# %%
#方法一每一次都show
plt.show()

# %%
#方法二
# %matplotlib inline #%魔法函数

# %%
plt.plot(a,b)

# %%
# %timeit np.arange(10)
# Out:
# The slowest run took 97.17 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 561 ns per loop

# %%
plt.plot(a,b,'r--')

# %%
c = [10,8,6]
d = [1,8,3]
plt.plot(a,b,'--',c,d,'*')
# Out:
# [<matplotlib.lines.Line2D at 0x1152c470>,
#  <matplotlib.lines.Line2D at 0x1152c710>]

# %%
t = np.arange(0.0,2.0,0.1)
t.size
# Out:
# 20

# %%
s = np.sin(t*np.pi)
plt.plot(t,s)

# %%
plt.plot(t,s,'r--',label='aaaa')
plt.plot(t*2,s,label='bbbb')
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
plt.legend()
